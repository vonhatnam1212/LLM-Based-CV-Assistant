# %% [markdown]
# # SQS

# %%
import boto3

# Tạo một client cho SQS
sqs = boto3.client("sqs", region_name = "ap-east-1")

# URL của hàng đợi SQS
queue_url = "https://sqs.ap-east-1.amazonaws.com/058264252521/upload-queue"

# Nhận thông điệp từ hàng đợi SQS
response = sqs.receive_message(
    QueueUrl=queue_url,
    AttributeNames=["All"],
    MaxNumberOfMessages=10,
    MessageAttributeNames=["All"],
    VisibilityTimeout=30,
    WaitTimeSeconds=0,
)

# Kiểm tra xem có thông điệp nào được nhận hay không
if "Messages" in response:
    for message in response["Messages"]:
        print(f"Message ID: {message['MessageId']}")
        print(f"Receipt Handle: {message['ReceiptHandle']}")
        print(f"Body: {message['Body']}")

        # Nếu bạn muốn xóa thông điệp sau khi xử lý
        # receipt_handle = message['ReceiptHandle']
        # sqs.delete_message(
        #     QueueUrl=queue_url,
        #     ReceiptHandle=receipt_handle
        # )
        # print('Deleted message: %s' % message['MessageId'])
else:
    print("No messages in the queue")
# Out:
# Message ID: e5fcfdee-f705-4621-b64b-52a9e08305cb
# Receipt Handle: ...
# Body: {"submissionId":111,"path":"https://vpbank-hackathon.s3.ap-east-1.amazonaws.com/CV/CV_72.pdf"}
# Message ID: 4adb0de4-2503-425e-967d-651a692a932f
# Receipt Handle: ...
# Body: {"submissionId":116,"path":"https://vpbank-hackathon.s3.ap-east-1.amazonaws.com/CV/CV_75.pdf"}
# Message ID: 510d2687-3d4e-4e38-b41f-4cdfd5b5fe05
# Receipt Handle: ...
# Body: {"submissionId":121,"path":"https://vpbank-hackathon.s3.ap-east-1.amazonaws.com/CV/CV_60.pdf"}

# %% [markdown]
# # S3

# %%
import urllib.parse
s3 = boto3.client("s3")

# URL của tệp S3
s3_url = 'https://vpbank-hackathon.s3.ap-east-1.amazonaws.com/CV/CV_18.doc'


# Phân tách bucket và key từ URL
parsed_url = urllib.parse.urlparse(s3_url)
bucket_name = parsed_url.netloc.split('.')[0]
file_key = parsed_url.path.lstrip('/')

# Phân tách bucket và key từ URL
bucket_name = 'your-bucket-name'
file_key = 'your-file-key'

# Tải tệp từ S3
response = s3.get_object(s3_url)
content = response['Body'].read()

# In nội dung của tệp (dưới dạng bytes)
print(content)

# Nếu tệp là văn bản, chuyển đổi bytes thành chuỗi
content_str = content.decode('utf-8')
print(content_str)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[14], line 11
#
#       8 file_key = 'your-file-key'
#
#      10 # Tải tệp từ S3
#
# ---> 11 response = s3.get_object(s3_url)
#
#      12 content = response['Body'].read()
#
#      14 # In nội dung của tệp (dưới dạng bytes)
#
#
#
# File c:\Users\ADMIN\anaconda3\envs\LLMs\lib\site-packages\botocore\client.py:561, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#
#     556 def _api_call(self, *args, **kwargs):
#
#     557     # We're accepting *args so that we can give a more helpful
#
#     558     # error message than TypeError: _api_call takes exactly
#
#     559     # 1 argument.
#
#     560     if args:
#
# --> 561         raise TypeError(
#
#     562             f"{py_operation_name}() only accepts keyword arguments."
#
#     563         )
#
# ...

# %%
import json
import requests
from pprint import pprint

# URL of the Java server endpoint
JAVA_SERVER_URL = "http://43.198.87.94:8081/api/hr/submission/updateSummary"  # Replace with your Java server address

# Data to be sent in the PUT request

# Send the PUT request
# response = requests.post(JAVA_SERVER_URL, json=data)
# Đường dẫn tới file JSONL
file_path = '../data/extract_CV.jsonl'

# Mở file và đọc từng dòng một
with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
        # Chuyển đổi mỗi dòng từ JSON sang dictionary
        json_data = json.loads(line.strip())
        # Thực hiện các thao tác với json_data
        data = {
            "submissionId": 123,
            "summary": {
                "candidate__skills": json_data["candidate__skills"]
            }
        }
        response = requests.put(JAVA_SERVER_URL, json=data)

        pprint(json_data)
        break
# Out:
# {'CV__Certifications': '1. KỸ SƯ THỦY VĂN HỌC\n'
#                        '2. Trường Đại học Tài nguyên và Môi trường TP.HCM '
#                        '(HUNRE)\n'
#                        '3. 2013\n'
#                        '4. unknown\n'
#                        '5. unknown\n'
#                        '\n'
#                        '1. Kĩ sư Thủy văn học\n'
#                        '2. Đài KTTV Khu Vực Nam Bộ\n'
#                        '3. 10/2017\n'
#                        '4. unknown\n'
#                        '5. Sử dụng thành thạo các phần mềm chuyên dụng ngành, '
#                        'Tăng cường khả năng sáng tạo và tính kiên trì, Thống '
#                        'kê, đo đạc số liệu dòng nước để phục vụ ngành liên '
#                        'quan, Nghiên cứu các phương pháp mới, số liệu mới của '
#                        'ngành',
#  'CV__Education': '1. Trường Đại học Tài nguyên và Môi trường TP.HCM (HUNRE)\n'
#                   '2. Kĩ sư Thủy văn học\n'
# ...

# %% [markdown]
# # BEDROCK

# %%
import boto3
import botocore

boto3_bedrock = boto3.client('bedrock-runtime', region_name="ap-south-1",)

# %%
from langchain.chains import LLMChain
from langchain.llms.bedrock import Bedrock
from langchain_aws.chat_models.bedrock import ChatBedrock
from langchain.prompts import ChatPromptTemplate
from langchain_core.prompts import PromptTemplate
from langchain.callbacks.base import BaseCallbackHandler
from langchain_core.runnables import ConfigurableField
class BedrockTokenCounter(BaseCallbackHandler):
    def __init__(self, llm):
        self.llm = llm
        self.input_tokens = 0
        self.output_tokens = 0

    def on_llm_start(self, serialized, prompts, **kwargs):
        for p in prompts:
            self.input_tokens = self.llm.get_num_tokens(p)

    def on_llm_end(self, response, **kwargs):
        results = response.flatten()
        for r in results:
            self.output_tokens = self.llm.get_num_tokens(r.generations[0][0].text)

# %%
llm = ChatBedrock(
    model_id="mistral.mixtral-8x7b-instruct-v0:1",
    region_name="ap-south-1",
    model_kwargs={
        "temperature": 0.5,
        # "max_tokens": 4096,
    },  # Set temperature here
    # client = boto3_bedrock
)
token_counter = BedrockTokenCounter(llm)
llm.callbacks = [token_counter]
QUERY_PROMPT = PromptTemplate(
    input_variables=["question"],
    template="""You are the assistant tasked with receiving a natural language query from a user and converting it into a query for a vector store. You will take issues related to skills, required skills, work experience, number of years of experience
        Here is the user's query: {question}""",
)
llm_chain = LLMChain(llm=llm, prompt=QUERY_PROMPT)
repharse_user_input = llm_chain.invoke("give me developer")
print("repharsee user input successful")
# Out:
# repharsee user input successful

# %%
llm.invoke("""1.\xa0Educational Qualifications     • Bachelor’s degree in Computer Science, Engineering, Mathematics or related field of study 2. Relevant Knowledge/ Expertise     • 5-10 years experiences in software development and at least 3 years in banking and fintech domain.     • An understanding of bank business processes, fintech solution and constraints. 3. Relevant Experience     • Expert in JAVA language, Spring boot, Hibernate, jpa, and solid work with IDE     • Net Framework should be considered added skill.     • Advanced Knowledge MS SQL, Oracle DBs     • Having knowledge about microservice, Kubernetes, ability to config EKS.     • Experience with source code management like Git, Gitlab, Jira.     • Good understanding on webservice SOAP/Restful, Standard message JSON, XML, OOP, Design pattern ...     • Knowledge on Angular, JS is big plus. 4. Skill     • Ability in English reading and writing (mandatory), and speaking, listening (preferable). 5. Others     • Teamwork, careful, attention to detail, logical thinking.     • Problem-solving\xa0skills, ability to work under high pressure and can-do attitude.     • Self-development and motivation skill.', 'resume_doc1': "Hello, I am Trần Hữu Đức, a Java Programmer with 2 years of experience in software engineering currently located in 136 Cầu Diễn Bắc Từ Liêm Hà Nội. My top skills encompass Java programming, Spring Boot, MySQL, and deployment using Docker. I have successfully executed an identity verification platform and managed a human resource system project for a Japanese client, showcasing my ability to deliver high-quality work under pressure. I am determined to further enhance my leadership skills and project management experience within the software development industry. \n\nThroughout my career at FPT Information System and FPT Software, I have engaged in coding, unit testing, performance testing, and deployment using various technologies such as Java Spring Boot, jBPM, Angular, Oracle, Struts, Docker, and more. I also completed an internship at VHC Soft where I worked on projects involving Java, jQuery/AJAX, HTML/CSS, and Oracle. My academic background includes a Bachelor's Degree in Information Systems from Hanoi University of Industry. \n\nIn terms of soft skills, I am known for being collaborative, friendly, eager to learn, highly responsible, and capable of handling high-pressure situations. My hard skills encompass a wide range of technologies including Java, Spring Boot, MySQL, Oracle, Docker, Ubuntu, Linux, HTML, JavaScript, AJAX, Gitlab, Eclipse, and more. I am fluent in Vietnamese and English, as well as in various programming languages and technologies such as Java, Spring Boot, Spring MVC, Spring Data JPA, Struts, MySQL, and more. I hold a certification as a Java Programmer, demonstrating my expertise in the field.\n\nMy short-term goal is to become a highly experienced leader by 2024 and focus on self-development and project management by 2025. In the long term, I aim to establish myself as a proficient project manager or software architect with a strong income by 2026 and beyond. I am a dedicated professional with a strong commitment to delivering top-notch results and I am excited about the opportunity to collaborate with your company in the near future. Thank you for considering my application.", 'resume_doc2': 'I am NGUYEN VAN QUAN, a skilled Java Developer based in Trung Hoa, Cau Giay, Ha Noi, with a strong passion for back-end web application development. Over the past 3 years, I have honed my expertise in Java, Spring Framework, and Spring Boot, alongside working with various technologies such as MySQL, JSON, RESTful APIs, SQL Server, and AWS. I take pride in my accomplishments, including leading projects like TDKL and File Manager, as well as contributing to Document_management and DCB projects. My experience at Toprate Company and TechcomBank has equipped me with valuable skills in project planning, team management, API development, and module deployment to customer servers. I hold a degree in Information Technology from FPT University, where I cultivated both soft skills like project planning and team management, as well as hard skills ranging from Java to AWS to CVS & CI/CD tools. With a goal to become a tech leader in the next 2 years, I am eager to continue enhancing my Java skills and taking on challenging projects that push my abilities to new heights. Contact me at nguyen9999@gmail.com or 038222999 to discuss potential opportunities further.', 'resume_doc3': 'With 2.5 years of experience as a Java Back-end Developer at reputable companies like MB Bank, FPT Software Ha Noi, TP Bank, and USOL Viet Nam, I have honed my skills in object-oriented programming, SOLID principles, and various design patterns. Specializing in the Spring Framework, I have successfully completed projects involving microservices architecture, JMS, SQL databases, and various development tools such as Eclipse, Visual Studio Code, and IntelliJ. Notable projects include developing a recruitment website for MB Bank using technologies like Spring Boot and Oracle Database and working on an E-Bank project at TP Bank utilizing Spring Boot, Spring Data JPA, and ActiveMQ. As a good team worker with strong communication skills in English and a TOEIC score of 600 points, I am now seeking a Java programmer position to further enhance my skills and contribute to the development of high-quality software products. Additionally, my certifications in Oracle Database and Amazon Web Services demonstrate my expertise in working with these technologies.', 'resume_doc4': "With 8 years of experience in development across various industries like Ecommerce, Healthcare, Medical, and Banking, I am Son Vu Tu, a Developer and Team Lead based in An Khánh, Hoài Đức, Hà Nội. Proficient in Java, Spring Boot, Hibernate, and more, I have successfully led teams in creating mobile money apps and web applications for medical equipment services. I am known for my strong knowledge of algorithms and ability to actively contribute as a team player. Some of my key achievements include developing functions for cash transactions, integrating Kafka messaging, and building systems for treasury business transactions. I have also worked on projects for public services translation, health insurance pricing, and medical equipment services, showcasing my diverse skill set. My educational background includes a degree in Computer Science from Ho Chi Minh City University of Industry. Equipped with certifications in Java Spring Boot, Liferay, and OpenMRS, I am proficient in various technologies like Spring Boot, Tapestry, and Liferay, along with databases like MySQL and Postgresql. My soft skills include adaptability, motivation, and strong teamwork abilities. I am now seeking challenging projects to further enhance my skills and contribute to impactful technology solutions. Contact me at tha999990@gmail.com or 0979819999, and let's create something great together.", 'resume_doc5': "With over 7 years of experience in software engineering, I am excited to present my CV as a Technical Lead, showcasing my expertise in Java, Spring Boot, Microservices, and other technologies like Kafka, Docker, and Jenkins. I have successfully led teams on various projects, including the development of the Digital Lending project at MBBank and the data analysis module at BaGps. My career highlights also include improving code using SOLID design principles at Bluesea Media & Technology JSC. As a Technical Lead at SimbaTech Company, I have managed teams on diverse projects, such as the Hai Quan MHS Project and developer training initiatives. My educational background includes a Master's Degree in Business Management from the National Economics University and a degree in Information Technology Engineering from Hung Yen University of Technical Education. In addition to my technical skills in Java, Microservice, and RESTful API, I possess soft skills in leadership, communication, and problem-solving, making me a well-rounded professional capable of driving innovation and delivering high-quality solutions in a challenging environment. My certifications as a Technical Lead and Software Engineer further demonstrate my commitment to excellence in the field of software development. With a passion for problem-solving and a drive for continuous improvement, I am eager to bring my technical expertise and leadership experience to a dynamic team that values collaboration and customer satisfaction.""")
# Out:
# AIMessage(content=' The first resume is from Trần Hữu Đức, a Java Programmer with 2 years of experience in software engineering. He has expertise in Java programming, Spring Boot, MySQL, and deployment using Docker. He has successfully executed an identity verification platform and managed a human resource system project for a Japanese client. He is determined to further enhance his leadership skills and project management experience within the software development industry.\n\nThe second resume is from NGUYEN VAN QUAN, a skilled Java Developer with a strong passion for back-end web application development. He has 3 years of experience in Java, Spring Framework, and Spring Boot, alongside working with various technologies such as MySQL, JSON, RESTful APIs, SQL Server, and AWS. He has led projects like TDKL and File Manager, and his experience at Toprate Company and TechcomBank has equipped him with valuable skills in project planning, team management, API development, and module depl
# ...
